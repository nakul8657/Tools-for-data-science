# %% [markdown]
# "# My Jupyter Notebook on IBM Watson Studio"

# %% [markdown]
# "**Nakul Rahate**\n\nData Scientis"

# %% [markdown]
# "_I am intrested in data science because i like to contribute in healthcare system_"

# %% [markdown]
# "###The below code should print 'Hello World!'"

# %%
print('Hello World!')
# Out:
# Hello World!

# %% [markdown]
# "> You miss 100% of the shots you don't take\n>\n - Wayne Gretzky\n - Micheal Scott\n\n<hr>\n\nMade with <3"
